# %%
# Import dependancies
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from citipy import citipy
from config import weather_api_key
import requests
# Create the URL for the API request
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Create a set of random latitude and longitude combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
#Add the latitudes and longitudes to a list
coordinates = list(lat_lngs)

# %%
# Create a list for holding the cities
cities = []
# Identify the nearest city for each latitude and longitude combination
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    
    # If the city is unique, then we will add it to the cities list
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count
len(cities)
# Out:
# 630

# %%
# Import the time library and the datetime module from the datetime library 
import time
from datetime import datetime

# %%
# Create an empty list to hold the weather data.
city_data = []

# Create counters.
record_count = 1
set_count = 1

# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Loop through all the cities in our list
for i, city in enumerate(cities):
    
    #Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >=50):
        set_count += 1
        record_count = 1
        time.sleep(60)
        
    # Create endpoint URL for each city.
    city_url = url + "&q=" + city.replace(" ", "+")
        
    # Log the URL,record, and set number and the city.
    print(f"Processing {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1


# Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                            "Lat": city_lat,
                            "Lng": city_lng,
                            "Max Temp": city_max_temp,
                            "Humidity": city_humidity,
                            "Cloudiness": city_clouds,
                            "Wind Speed": city_wind,
                            "Country": city_country,
                            "Date": city_date})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing 1 of Set 1 | atuona
# Processing 2 of Set 1 | khatanga
# Processing 3 of Set 1 | hasaki
# Processing 4 of Set 1 | arraial do cabo
# Processing 5 of Set 1 | roald
# Processing 6 of Set 1 | punta arenas
# Processing 7 of Set 1 | metro
# Processing 8 of Set 1 | butaritari
# Processing 9 of Set 1 | sitka
# Processing 10 of Set 1 | salinopolis
# Processing 11 of Set 1 | piacabucu
# Processing 12 of Set 1 | san patricio
# Processing 13 of Set 1 | guanica
# Processing 14 of Set 1 | cape town
# Processing 15 of Set 1 | port alfred
# Processing 16 of Set 1 | east london
# Processing 17 of Set 1 | rabat
# Processing 18 of Set 1 | faanui
# Processing 19 of Set 1 | hobart
# Processing 20 of Set 1 | smolenka
# Processing 21 of Set 1 | kenai
# Processing 22 of Set 1 | busselton
# Processing 23 of Set 1 | bend
# Processing 24 of Set 1 | mataura
# Processing 25 of Set 1 | bluff
# Processing 26 of Set 1 | georgetown
# Processing 27 of Set 1 | lorengau
# Processing 28 of Set 1 | ushuaia
# Processing 29 of Set 1 | codrington
# Processing 30 of Set 1 | carnarvon
# Processing 31 of Set 1 | benguela
# Processing 32 of Set 1 | barrow
# Processing 33 of Set 1 | smolensk
# Processing 34 of Set 1 | dikson
# Processing 35 of Set 1 | ancud
# Processing 36 of Set 1 | hammerfest
# Processing 37 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing 38 of Set 1 | chachapoyas
# Processing 39 of Set 1 | broome
# Processing 40 of Set 1 | gondanglegi
# Processing 41 of Set 1 | luena
# Processing 42 of Set 1 | bengkulu
# Processing 43 of Set 1 | cabo san lucas
# Processing 44 of Set 1 | provideniya
# Processing 45 of Set 1 | kieta
# Processing 46 of Set 1 | jaboticabal
# Processing 47 of Set 1 | cockburn town
# Processing 48 of Set 1 | vaini
# Processing 49 of Set 1 | molchanovo
# Processing 50 of Set 1 | albany
# Processing 1 of Set 2 | cabedelo
# Processing 2 of Set 2 | davidson
# Processing 3 of Set 2 | kungsbacka
# Processing 4 of Set 2 | maldonado
# Processing 5 of Set 2 | tiksi
# Processing 6 of Set 2 | abalak
# Processing 7 of Set 2 | inirida
# Processing 8 of Set 2 | mahebourg
# Processing 9 of Set 2 | qaanaaq
# Processing 10 of Set 2 | teahupoo
# Processing 11 of Set 2 | sinnamary
# Processing 12 of Set 2 | puerto del rosario
# Processing 13 of Set 2 | ponta do sol
# Processing 14 of Set 2 | clyde river
# Processing 15 of Set 2 | puerto ayora
# Processing 16 of Set 2 | antalaha
# Processing 17 of Set 2 | rikitea
# Processing 18 of Set 2 | buraydah
# Processing 19 of Set 2 | paamiut
# Processing 20 of Set 2 | batagay-alyta
# Processing 21 of Set 2 | tuktoyaktuk
# Processing 22 of Set 2 | maniitsoq
# Processing 23 of Set 2 | salym
# Processing 24 of Set 2 | kapaa
# Processing 25 of Set 2 | longyearbyen
# Processing 26 of Set 2 | solnechnyy
# Processing 27 of Set 2 | egvekinot
# Processing 28 of Set 2 | torrington
# Processing 29 of Set 2 | ailigandi
# Processing 30 of Set 2 | pozo colorado
# Processing 31 of Set 2 | airai
# Processing 32 of Set 2 | hermanus
# Processing 33 of Set 2 | boyolangu
# Processing 34 of Set 2 | carman
# Processing 35 of Set 2 | crotone
# Processing 36 of Set 2 | taolanaro
# City not found. Skipping...
# Processing 37 of Set 2 | marsh harbour
# Processing 38 of Set 2 | miandrivazo
# Processing 39 of Set 2 | kiama
# Processing 40 of Set 2 | shima
# Processing 41 of Set 2 | kavieng
# Processing 42 of Set 2 | jujuy
# City not found. Skipping...
# Processing 43 of Set 2 | catuday
# Processing 44 of Set 2 | teeswater
# Processing 45 of Set 2 | ban tak
# Processing 46 of Set 2 | aksarka
# Processing 47 of Set 2 | hovd
# Processing 48 of Set 2 | sistranda
# Processing 49 of Set 2 | port elizabeth
# Processing 50 of Set 2 | bage
# Processing 1 of Set 3 | kununurra
# Processing 2 of Set 3 | nizhneyansk
# City not found. Skipping...
# Processing 3 of Set 3 | rawson
# Processing 4 of Set 3 | mormugao
# Processing 5 of Set 3 | saldanha
# Processing 6 of Set 3 | sobolevo
# Processing 7 of Set 3 | bela
# Processing 8 of Set 3 | cernosice
# Processing 9 of Set 3 | roebourne
# Processing 10 of Set 3 | klaksvik
# Processing 11 of Set 3 | jamestown
# Processing 12 of Set 3 | torbay
# Processing 13 of Set 3 | kaitangata
# Processing 14 of Set 3 | castro
# Processing 15 of Set 3 | avarua
# Processing 16 of Set 3 | agudos
# Processing 17 of Set 3 | fortuna
# Processing 18 of Set 3 | norman wells
# Processing 19 of Set 3 | burica
# City not found. Skipping...
# Processing 20 of Set 3 | hofn
# Processing 21 of Set 3 | kodiak
# Processing 22 of Set 3 | tura
# Processing 23 of Set 3 | maracaibo
# Processing 24 of Set 3 | chuy
# Processing 25 of Set 3 | attawapiskat
# City not found. Skipping...
# Processing 26 of Set 3 | deputatskiy
# Processing 27 of Set 3 | khandyga
# Processing 28 of Set 3 | tsumeb
# Processing 29 of Set 3 | nkan
# Processing 30 of Set 3 | naze
# Processing 31 of Set 3 | halifax
# Processing 32 of Set 3 | labuhan
# Processing 33 of Set 3 | zapolyarnyy
# Processing 34 of Set 3 | rungata
# City not found. Skipping...
# Processing 35 of Set 3 | saleaula
# City not found. Skipping...
# Processing 36 of Set 3 | vagur
# Processing 37 of Set 3 | bilibino
# Processing 38 of Set 3 | broken hill
# Processing 39 of Set 3 | amot
# Processing 40 of Set 3 | dumas
# Processing 41 of Set 3 | lavrentiya
# Processing 42 of Set 3 | puerto escondido
# Processing 43 of Set 3 | panguna
# Processing 44 of Set 3 | fomboni
# Processing 45 of Set 3 | tasiilaq
# Processing 46 of Set 3 | port shepstone
# Processing 47 of Set 3 | macomb
# Processing 48 of Set 3 | severo-kurilsk
# Processing 49 of Set 3 | barentsburg
# City not found. Skipping...
# Processing 50 of Set 3 | sola
# Processing 1 of Set 4 | bredasdorp
# Processing 2 of Set 4 | ahipara
# Processing 3 of Set 4 | merauke
# Processing 4 of Set 4 | kichera
# Processing 5 of Set 4 | grand river south east
# City not found. Skipping...
# Processing 6 of Set 4 | faya
# Processing 7 of Set 4 | westport
# Processing 8 of Set 4 | mount gambier
# Processing 9 of Set 4 | vanimo
# Processing 10 of Set 4 | hilo
# Processing 11 of Set 4 | bambous virieux
# Processing 12 of Set 4 | verkhovazhye
# Processing 13 of Set 4 | jipijapa
# Processing 14 of Set 4 | andra
# Processing 15 of Set 4 | hambantota
# Processing 16 of Set 4 | utiroa
# City not found. Skipping...
# Processing 17 of Set 4 | tiznit
# Processing 18 of Set 4 | bereda
# Processing 19 of Set 4 | marsabit
# Processing 20 of Set 4 | susanville
# Processing 21 of Set 4 | barcarena
# Processing 22 of Set 4 | kruisfontein
# Processing 23 of Set 4 | asau
# Processing 24 of Set 4 | gunjur
# Processing 25 of Set 4 | thompson
# Processing 26 of Set 4 | mayo
# Processing 27 of Set 4 | moree
# Processing 28 of Set 4 | camacha
# Processing 29 of Set 4 | khapa
# Processing 30 of Set 4 | viedma
# Processing 31 of Set 4 | maple creek
# Processing 32 of Set 4 | saint-philippe
# Processing 33 of Set 4 | sungairaya
# Processing 34 of Set 4 | berga
# Processing 35 of Set 4 | itoman
# Processing 36 of Set 4 | korla
# Processing 37 of Set 4 | bosaso
# Processing 38 of Set 4 | ribeira grande
# Processing 39 of Set 4 | mar del plata
# Processing 40 of Set 4 | north bend
# Processing 41 of Set 4 | upernavik
# Processing 42 of Set 4 | marcona
# City not found. Skipping...
# Processing 43 of Set 4 | dzhusaly
# City not found. Skipping...
# Processing 44 of Set 4 | podbelsk
# City not found. Skipping...
# Processing 45 of Set 4 | ostrovnoy
# Processing 46 of Set 4 | chokurdakh
# Processing 47 of Set 4 | nikolskoye
# Processing 48 of Set 4 | sumenep
# Processing 49 of Set 4 | pevek
# Processing 50 of Set 4 | high level
# Processing 1 of Set 5 | lebu
# Processing 2 of Set 5 | fuerte olimpo
# Processing 3 of Set 5 | ust-kuyga
# Processing 4 of Set 5 | bolshaya irba
# City not found. Skipping...
# Processing 5 of Set 5 | boa vista
# Processing 6 of Set 5 | andilamena
# Processing 7 of Set 5 | cidreira
# Processing 8 of Set 5 | teya
# Processing 9 of Set 5 | yellowknife
# Processing 10 of Set 5 | yinchuan
# Processing 11 of Set 5 | kracheh
# City not found. Skipping...
# Processing 12 of Set 5 | yarmouth
# Processing 13 of Set 5 | padang
# Processing 14 of Set 5 | iqaluit
# Processing 15 of Set 5 | ekhabi
# Processing 16 of Set 5 | acapulco
# Processing 17 of Set 5 | sechura
# Processing 18 of Set 5 | sao joao da ponte
# Processing 19 of Set 5 | abu dhabi
# Processing 20 of Set 5 | labutta
# City not found. Skipping...
# Processing 21 of Set 5 | astoria
# Processing 22 of Set 5 | omboue
# Processing 23 of Set 5 | victoria
# Processing 24 of Set 5 | mys shmidta
# City not found. Skipping...
# Processing 25 of Set 5 | tautira
# Processing 26 of Set 5 | monster
# Processing 27 of Set 5 | ulundi
# Processing 28 of Set 5 | pacific grove
# Processing 29 of Set 5 | kismayo
# Processing 30 of Set 5 | lensk
# Processing 31 of Set 5 | vero beach
# Processing 32 of Set 5 | san andres
# Processing 33 of Set 5 | pangnirtung
# Processing 34 of Set 5 | samusu
# City not found. Skipping...
# Processing 35 of Set 5 | new plymouth
# Processing 36 of Set 5 | biak
# Processing 37 of Set 5 | kutum
# Processing 38 of Set 5 | ilheus
# Processing 39 of Set 5 | bethel
# Processing 40 of Set 5 | kanniyakumari
# Processing 41 of Set 5 | kulhudhuffushi
# Processing 42 of Set 5 | port macquarie
# Processing 43 of Set 5 | bunia
# Processing 44 of Set 5 | jinchang
# Processing 45 of Set 5 | cabinda
# Processing 46 of Set 5 | lolua
# City not found. Skipping...
# Processing 47 of Set 5 | orbetello
# Processing 48 of Set 5 | erenhot
# Processing 49 of Set 5 | coronel
# Processing 50 of Set 5 | port lincoln
# Processing 1 of Set 6 | tomatlan
# Processing 2 of Set 6 | bonthe
# Processing 3 of Set 6 | pareora
# Processing 4 of Set 6 | tsihombe
# City not found. Skipping...
# Processing 5 of Set 6 | tukrah
# Processing 6 of Set 6 | prata
# Processing 7 of Set 6 | pietarsaari
# Processing 8 of Set 6 | makakilo city
# Processing 9 of Set 6 | kahului
# Processing 10 of Set 6 | bure
# Processing 11 of Set 6 | manono
# Processing 12 of Set 6 | nyurba
# Processing 13 of Set 6 | itaqui
# Processing 14 of Set 6 | banjar
# Processing 15 of Set 6 | srednekolymsk
# Processing 16 of Set 6 | saint george
# Processing 17 of Set 6 | date
# Processing 18 of Set 6 | los llanos de aridane
# Processing 19 of Set 6 | udachnyy
# Processing 20 of Set 6 | port blair
# Processing 21 of Set 6 | new norfolk
# Processing 22 of Set 6 | half moon bay
# Processing 23 of Set 6 | batemans bay
# Processing 24 of Set 6 | amderma
# City not found. Skipping...
# Processing 25 of Set 6 | sao luis do quitunde
# Processing 26 of Set 6 | touros
# Processing 27 of Set 6 | petropavlovka
# Processing 28 of Set 6 | portland
# Processing 29 of Set 6 | alice springs
# Processing 30 of Set 6 | tanggu
# Processing 31 of Set 6 | pasighat
# Processing 32 of Set 6 | vostok
# Processing 33 of Set 6 | ossora
# Processing 34 of Set 6 | saint-pierre
# Processing 35 of Set 6 | saint-augustin
# Processing 36 of Set 6 | burnie
# Processing 37 of Set 6 | hebertville
# City not found. Skipping...
# Processing 38 of Set 6 | hithadhoo
# Processing 39 of Set 6 | gushikawa
# Processing 40 of Set 6 | eldikan
# City not found. Skipping...
# Processing 41 of Set 6 | ji-parana
# City not found. Skipping...
# Processing 42 of Set 6 | daru
# Processing 43 of Set 6 | bay roberts
# Processing 44 of Set 6 | aksu
# Processing 45 of Set 6 | bording
# Processing 46 of Set 6 | manta
# Processing 47 of Set 6 | vao
# Processing 48 of Set 6 | luderitz
# Processing 49 of Set 6 | sakakah
# Processing 50 of Set 6 | virginia beach
# Processing 1 of Set 7 | umzimvubu
# City not found. Skipping...
# Processing 2 of Set 7 | toppenish
# Processing 3 of Set 7 | caravelas
# Processing 4 of Set 7 | agirish
# Processing 5 of Set 7 | krasnokamensk
# Processing 6 of Set 7 | kuching
# Processing 7 of Set 7 | antibes
# Processing 8 of Set 7 | taltal
# Processing 9 of Set 7 | lipin bor
# Processing 10 of Set 7 | berdigestyakh
# Processing 11 of Set 7 | aljezur
# Processing 12 of Set 7 | castlegar
# Processing 13 of Set 7 | lompoc
# Processing 14 of Set 7 | matagami
# Processing 15 of Set 7 | moranbah
# Processing 16 of Set 7 | pitimbu
# Processing 17 of Set 7 | nanortalik
# Processing 18 of Set 7 | husavik
# Processing 19 of Set 7 | bani
# Processing 20 of Set 7 | sidlaghatta
# Processing 21 of Set 7 | imbituba
# Processing 22 of Set 7 | tarudant
# City not found. Skipping...
# Processing 23 of Set 7 | balakhninskiy
# Processing 24 of Set 7 | sentyabrskiy
# City not found. Skipping...
# Processing 25 of Set 7 | batamshinskiy
# Processing 26 of Set 7 | gidam
# Processing 27 of Set 7 | salalah
# Processing 28 of Set 7 | malwan
# City not found. Skipping...
# Processing 29 of Set 7 | nishihara
# Processing 30 of Set 7 | alofi
# Processing 31 of Set 7 | zhiryatino
# Processing 32 of Set 7 | kantunilkin
# Processing 33 of Set 7 | san rafael
# Processing 34 of Set 7 | nyaunglebin
# Processing 35 of Set 7 | belmonte
# Processing 36 of Set 7 | klamath falls
# Processing 37 of Set 7 | saskylakh
# Processing 38 of Set 7 | atar
# Processing 39 of Set 7 | inuvik
# Processing 40 of Set 7 | bolshegrivskoye
# City not found. Skipping...
# Processing 41 of Set 7 | rosita
# Processing 42 of Set 7 | damietta
# Processing 43 of Set 7 | myitkyina
# Processing 44 of Set 7 | san quintin
# Processing 45 of Set 7 | shimoda
# Processing 46 of Set 7 | kloulklubed
# Processing 47 of Set 7 | talara
# Processing 48 of Set 7 | hami
# Processing 49 of Set 7 | houma
# Processing 50 of Set 7 | alcaniz
# Processing 1 of Set 8 | calama
# Processing 2 of Set 8 | seoul
# Processing 3 of Set 8 | lukovetskiy
# Processing 4 of Set 8 | sambava
# Processing 5 of Set 8 | zvenigovo
# Processing 6 of Set 8 | mantenopolis
# Processing 7 of Set 8 | inhambane
# Processing 8 of Set 8 | laela
# Processing 9 of Set 8 | harper
# Processing 10 of Set 8 | constitucion
# Processing 11 of Set 8 | sao joao da barra
# Processing 12 of Set 8 | balabac
# Processing 13 of Set 8 | avera
# Processing 14 of Set 8 | basco
# Processing 15 of Set 8 | zakamensk
# Processing 16 of Set 8 | pioner
# Processing 17 of Set 8 | sabla
# Processing 18 of Set 8 | san juan
# Processing 19 of Set 8 | charters towers
# Processing 20 of Set 8 | belushya guba
# City not found. Skipping...
# Processing 21 of Set 8 | guerrero negro
# Processing 22 of Set 8 | kattivakkam
# Processing 23 of Set 8 | pathein
# Processing 24 of Set 8 | karpuninskiy
# City not found. Skipping...
# Processing 25 of Set 8 | santa lucia
# Processing 26 of Set 8 | talnakh
# Processing 27 of Set 8 | graaff-reinet
# Processing 28 of Set 8 | tuatapere
# Processing 29 of Set 8 | ransang
# Processing 30 of Set 8 | cayenne
# Processing 31 of Set 8 | shelburne
# Processing 32 of Set 8 | richards bay
# Processing 33 of Set 8 | kozova
# Processing 34 of Set 8 | tazovskiy
# Processing 35 of Set 8 | san ramon
# Processing 36 of Set 8 | coalinga
# Processing 37 of Set 8 | gubkinskiy
# Processing 38 of Set 8 | vilyuysk
# Processing 39 of Set 8 | gimli
# Processing 40 of Set 8 | zhuanghe
# Processing 41 of Set 8 | sijunjung
# Processing 42 of Set 8 | thinadhoo
# Processing 43 of Set 8 | anchorage
# Processing 44 of Set 8 | killybegs
# Processing 45 of Set 8 | marzuq
# Processing 46 of Set 8 | payson
# Processing 47 of Set 8 | cap malheureux
# Processing 48 of Set 8 | katsuura
# Processing 49 of Set 8 | saint-honore
# Processing 50 of Set 8 | yerbogachen
# Processing 1 of Set 9 | port-gentil
# Processing 2 of Set 9 | meulaboh
# Processing 3 of Set 9 | qaqortoq
# Processing 4 of Set 9 | esmeraldas
# Processing 5 of Set 9 | chivay
# Processing 6 of Set 9 | torbat-e jam
# Processing 7 of Set 9 | jilmah
# City not found. Skipping...
# Processing 8 of Set 9 | mapiripan
# Processing 9 of Set 9 | ingham
# Processing 10 of Set 9 | balkanabat
# Processing 11 of Set 9 | samarai
# Processing 12 of Set 9 | geraldton
# Processing 13 of Set 9 | moses lake
# Processing 14 of Set 9 | tonantins
# Processing 15 of Set 9 | tromso
# Processing 16 of Set 9 | rio grande
# Processing 17 of Set 9 | hope
# Processing 18 of Set 9 | presidencia roque saenz pena
# Processing 19 of Set 9 | moengo
# Processing 20 of Set 9 | yulara
# Processing 21 of Set 9 | itamaraju
# Processing 22 of Set 9 | berezovyy
# Processing 23 of Set 9 | northam
# Processing 24 of Set 9 | rudnogorsk
# Processing 25 of Set 9 | bada
# Processing 26 of Set 9 | maiduguri
# Processing 27 of Set 9 | kostomuksha
# Processing 28 of Set 9 | waingapu
# Processing 29 of Set 9 | vieux-habitants
# Processing 30 of Set 9 | malanville
# Processing 31 of Set 9 | pacasmayo
# Processing 32 of Set 9 | port-cartier
# Processing 33 of Set 9 | obregon
# Processing 34 of Set 9 | ambon
# Processing 35 of Set 9 | palmer
# Processing 36 of Set 9 | sorvag
# City not found. Skipping...
# Processing 37 of Set 9 | sahuaripa
# Processing 38 of Set 9 | mishan
# Processing 39 of Set 9 | bandarbeyla
# Processing 40 of Set 9 | chapleau
# Processing 41 of Set 9 | tuy hoa
# Processing 42 of Set 9 | bialystok
# Processing 43 of Set 9 | cherskiy
# Processing 44 of Set 9 | flinders
# Processing 45 of Set 9 | ngunguru
# Processing 46 of Set 9 | haibowan
# City not found. Skipping...
# Processing 47 of Set 9 | iskateley
# Processing 48 of Set 9 | trhove sviny
# Processing 49 of Set 9 | nuuk
# Processing 50 of Set 9 | canala
# Processing 1 of Set 10 | sisimiut
# Processing 2 of Set 10 | kavaratti
# Processing 3 of Set 10 | alta
# Processing 4 of Set 10 | buala
# Processing 5 of Set 10 | ajaccio
# Processing 6 of Set 10 | sataua
# City not found. Skipping...
# Processing 7 of Set 10 | tidore
# City not found. Skipping...
# Processing 8 of Set 10 | olinda
# Processing 9 of Set 10 | dingle
# Processing 10 of Set 10 | concordia
# Processing 11 of Set 10 | dongsheng
# Processing 12 of Set 10 | zdvinsk
# Processing 13 of Set 10 | liyang
# Processing 14 of Set 10 | ellisras
# Processing 15 of Set 10 | gisborne
# Processing 16 of Set 10 | nhulunbuy
# Processing 17 of Set 10 | sioux lookout
# Processing 18 of Set 10 | kiunga
# Processing 19 of Set 10 | yurty
# Processing 20 of Set 10 | bolungarvik
# City not found. Skipping...
# Processing 21 of Set 10 | ocampo
# Processing 22 of Set 10 | imperia
# Processing 23 of Set 10 | linqiong
# Processing 24 of Set 10 | mehamn
# Processing 25 of Set 10 | fairbanks
# Processing 26 of Set 10 | kaeo
# Processing 27 of Set 10 | shingu
# Processing 28 of Set 10 | zhezkazgan
# Processing 29 of Set 10 | nyaregyhaza
# Processing 30 of Set 10 | murray bridge
# Processing 31 of Set 10 | ilulissat
# Processing 32 of Set 10 | natal
# Processing 33 of Set 10 | leningradskiy
# Processing 34 of Set 10 | vardo
# Processing 35 of Set 10 | dongzhen
# Processing 36 of Set 10 | laguna
# Processing 37 of Set 10 | abha
# Processing 38 of Set 10 | cartagena del chaira
# Processing 39 of Set 10 | alcudia
# Processing 40 of Set 10 | morehead
# Processing 41 of Set 10 | kaseda
# Processing 42 of Set 10 | vila franca do campo
# Processing 43 of Set 10 | maningrida
# Processing 44 of Set 10 | aklavik
# Processing 45 of Set 10 | dunedin
# Processing 46 of Set 10 | san policarpo
# Processing 47 of Set 10 | arshan
# Processing 48 of Set 10 | west plains
# Processing 49 of Set 10 | weatherford
# Processing 50 of Set 10 | petropavlovsk-kamchatskiy
# Processing 1 of Set 11 | akyab
# Processing 2 of Set 11 | eyl
# Processing 3 of Set 11 | isangel
# Processing 4 of Set 11 | tanete
# Processing 5 of Set 11 | yaring
# Processing 6 of Set 11 | vaitupu
# City not found. Skipping...
# Processing 7 of Set 11 | tucurui
# Processing 8 of Set 11 | mahanoro
# Processing 9 of Set 11 | hueytown
# Processing 10 of Set 11 | key largo
# Processing 11 of Set 11 | bonavista
# Processing 12 of Set 11 | tieling
# Processing 13 of Set 11 | martapura
# Processing 14 of Set 11 | phan rang
# City not found. Skipping...
# Processing 15 of Set 11 | zaritap
# Processing 16 of Set 11 | ola
# Processing 17 of Set 11 | emerald
# Processing 18 of Set 11 | vaovai
# City not found. Skipping...
# Processing 19 of Set 11 | grindavik
# Processing 20 of Set 11 | sorland
# Processing 21 of Set 11 | loandjili
# Processing 22 of Set 11 | pinsk
# Processing 23 of Set 11 | sao marcos
# Processing 24 of Set 11 | nara
# Processing 25 of Set 11 | kalynivka
# Processing 26 of Set 11 | zanjan
# Processing 27 of Set 11 | svetlaya
# Processing 28 of Set 11 | laredo
# Processing 29 of Set 11 | te anau
# Processing 30 of Set 11 | kapoeta
# Processing 31 of Set 11 | puertollano
# Processing 32 of Set 11 | muros
# Processing 33 of Set 11 | wonthaggi
# Processing 34 of Set 11 | henties bay
# Processing 35 of Set 11 | alexandria
# Processing 36 of Set 11 | olafsvik
# Processing 37 of Set 11 | mrirt
# City not found. Skipping...
# Processing 38 of Set 11 | kalabo
# Processing 39 of Set 11 | sao filipe
# Processing 40 of Set 11 | mount isa
# Processing 41 of Set 11 | port pirie
# Processing 42 of Set 11 | chilca
# Processing 43 of Set 11 | the valley
# Processing 44 of Set 11 | namibe
# Processing 45 of Set 11 | yar-sale
# Processing 46 of Set 11 | nayoro
# Processing 47 of Set 11 | vangaindrano
# Processing 48 of Set 11 | rocha
# Processing 49 of Set 11 | edeia
# Processing 50 of Set 11 | nalut
# Processing 1 of Set 12 | praxedis guerrero
# Processing 2 of Set 12 | saiha
# Processing 3 of Set 12 | sakaiminato
# Processing 4 of Set 12 | changli
# Processing 5 of Set 12 | namtsy
# Processing 6 of Set 12 | kachug
# Processing 7 of Set 12 | margate
# Processing 8 of Set 12 | motygino
# Processing 9 of Set 12 | axim
# Processing 10 of Set 12 | tiarei
# Processing 11 of Set 12 | coahuayana
# Processing 12 of Set 12 | port hedland
# Processing 13 of Set 12 | fayaoue
# Processing 14 of Set 12 | nelson bay
# Processing 15 of Set 12 | zhigansk
# Processing 16 of Set 12 | beringovskiy
# Processing 17 of Set 12 | yongan
# Processing 18 of Set 12 | hargeysa
# Processing 19 of Set 12 | galle
# Processing 20 of Set 12 | el dovio
# Processing 21 of Set 12 | celestun
# Processing 22 of Set 12 | manawar
# Processing 23 of Set 12 | kralendijk
# Processing 24 of Set 12 | sumbawa
# City not found. Skipping...
# Processing 25 of Set 12 | pahrump
# Processing 26 of Set 12 | chernyshevskiy
# Processing 27 of Set 12 | namatanai
# Processing 28 of Set 12 | lagoa
# Processing 29 of Set 12 | sheregesh
# Processing 30 of Set 12 | tungor
# Processing 31 of Set 12 | sergeyevka
# Processing 32 of Set 12 | leshukonskoye
# Processing 33 of Set 12 | hobyo
# Processing 34 of Set 12 | gidole
# Processing 35 of Set 12 | ulaanbaatar
# Processing 36 of Set 12 | bandiagara
# Processing 37 of Set 12 | hihya
# Processing 38 of Set 12 | sancel
# Processing 39 of Set 12 | gorkovskoye
# City not found. Skipping...
# Processing 40 of Set 12 | narsaq
# Processing 41 of Set 12 | leh
# Processing 42 of Set 12 | warqla
# City not found. Skipping...
# Processing 43 of Set 12 | santiago
# Processing 44 of Set 12 | colares
# Processing 45 of Set 12 | qasigiannguit
# Processing 46 of Set 12 | vung tau
# Processing 47 of Set 12 | kaihua
# Processing 48 of Set 12 | jalu
# Processing 49 of Set 12 | taki
# Processing 50 of Set 12 | mancora
# Processing 1 of Set 13 | marawi
# Processing 2 of Set 13 | awjilah
# Processing 3 of Set 13 | phulabani
# Processing 4 of Set 13 | bria
# Processing 5 of Set 13 | vytegra
# Processing 6 of Set 13 | khuzhir
# Processing 7 of Set 13 | chandur bazar
# Processing 8 of Set 13 | vitim
# Processing 9 of Set 13 | tabuk
# Processing 10 of Set 13 | deming
# Processing 11 of Set 13 | winslow
# Processing 12 of Set 13 | doha
# Processing 13 of Set 13 | karratha
# Processing 14 of Set 13 | bandar-e lengeh
# Processing 15 of Set 13 | svetlyy
# Processing 16 of Set 13 | malia
# Processing 17 of Set 13 | college
# Processing 18 of Set 13 | chara
# Processing 19 of Set 13 | nouadhibou
# Processing 20 of Set 13 | tsiroanomandidy
# Processing 21 of Set 13 | kedougou
# Processing 22 of Set 13 | viloco
# Processing 23 of Set 13 | kuytun
# Processing 24 of Set 13 | puerto baquerizo moreno
# Processing 25 of Set 13 | high rock
# Processing 26 of Set 13 | santa cruz del sur
# Processing 27 of Set 13 | sibu
# Processing 28 of Set 13 | oksfjord
# Processing 29 of Set 13 | qurayyat
# Processing 30 of Set 13 | uribia
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
len(city_data)
# Out:
# 554

# %%
# Convert the array of dictionalries to a Pandas DataFrame
city_data_df = pd.DataFrame(city_data)

new_column_order = ["City", "Country", "Date", "Lat", "Lng", "Max Temp", "Humidity", "Cloudiness", "Wind Speed"]
city_data_df = city_data_df[new_column_order]
city_data_df
# Out:
#             City Country                 Date      Lat       Lng  Max Temp  \
# 0          Vaini      TO  2021-11-23 03:29:21 -21.2000 -175.2000     84.36
# 1      Cape Town      ZA  2021-11-23 03:30:03 -33.9258   18.4232     63.10
# 2    New Norfolk      AU  2021-11-23 03:34:14 -42.7826  147.0587     74.91
# 3    Yellowknife      CA  2021-11-23 03:31:18  62.4560 -114.3525     -8.59
# 4          Mongo      TD  2021-11-23 03:34:14  12.1844   18.6930     74.98
# ..           ...     ...                  ...      ...       ...       ...
# 549       Omboue      GA  2021-11-23 03:48:34  -1.5746    9.2618     76.75
# 550       Baykit      RU  2021-11-23 03:48:35  61.6700   96.3700     15.87
# 551     Bilibino      RU  2021-11-23 03:48:35  68.0546  166.4372    -21.59
# 552   Le Vauclin      MQ  2021-11-23 03:48:35  14.5452  -60.8388     76.84
# 553      Bontang      ID  2021-11-23 03:45:25   0.1333  117.5000     85.33
#
#      Humidity  Cloudiness  Wind Speed
# 0          79          40        5.75
# 1          70           0       19.57
# 2          40         100        1.99
# 3          77          40        3.00
# 4          24         100        4.63
# ..        ...         ...         ...
# 549        91         100        4.25
# 550        95         100        3.29
# 551        89           4        3.71
# 552        88          75        2.30
# 553        68          54        6.38
#
# [554 rows x 9 columns]

# %%
#Create the output file (CSV)
output_data_file = "weather_data/cities.csv"
# Export the City_Data into a CSV
city_data_df.to_csv(output_data_file, index_label="City_ID")

# %%
# Extract relevant fields from the DataFrame for plotting
lats = city_data_df["Lat"]
max_temps = city_data_df["Max Temp"]
humidity = city_data_df["Humidity"]
cloudiness = city_data_df["Cloudiness"]
wind_speed = city_data_df["Wind Speed"]

# %%
# Import the time module
import time
# Build the scatter plot for latitude vs max temperature
plt.scatter(lats, max_temps, edgecolor="black", linewidth = 1, marker = "o", alpha=.08, label="Cities")

# Incorperate the other graph properties
plt.title(f"City Latitude vs Max Temperature "+ time.strftime("%x"))
plt.ylabel("Max Temperature (F)")
plt.xlabel("Latitude")
plt.grid(True)

# Save the figure
plt.savefig("weather_data/fig.png")
                                                              
# Show plot
plt.show()

# %%
# Build the scatter plots for latitude vs. humidity.
plt.scatter(lats,
            humidity,
            edgecolor="black", linewidths=1, marker="o",
            alpha=0.8, label="Cities")

# Incorporate the other graph properties.
plt.title(f"City Latitude vs. Humidity "+ time.strftime("%x"))
plt.ylabel("Humidity (%)")
plt.xlabel("Latitude")
plt.grid(True)
# Save the figure.
plt.savefig("weather_data/Fig2.png")
# Show plot.
plt.show()

# %%
# Build the scatter plots for latitude vs. cloudiness.
plt.scatter(lats,
            cloudiness,
            edgecolor="black", linewidths=1, marker="o",
            alpha=0.8, label="Cities")

# Incorporate the other graph properties.
plt.title(f"City Latitude vs. Cloudiness (%) "+ time.strftime("%x"))
plt.ylabel("Cloudiness (%)")
plt.xlabel("Latitude")
plt.grid(True)
# Save the figure.
plt.savefig("weather_data/Fig3.png")
# Show plot.
plt.show()

# %%
# Build the scatter plots for latitude vs. wind speed.
plt.scatter(lats,
            wind_speed,
            edgecolor="black", linewidths=1, marker="o",
            alpha=0.8, label="Cities")

# Incorporate the other graph properties.
plt.title(f"City Latitude vs. Wind Speed "+ time.strftime("%x"))
plt.ylabel("Wind Speed (mph)")
plt.xlabel("Latitude")
plt.grid(True)
# Save the figure.
plt.savefig("weather_data/Fig4.png")
# Show plot.
plt.show()

# %%
# Import linregress
from scipy.stats import linregress

# Create a function to create perform linear regression on the weather data
# and plot a regression line and the equation with the data.
def plot_linear_regression(x_values, y_values, title, y_label, text_coordinates):

    # Run regression on hemisphere weather data.
    (slope, intercept, r_value, p_value, std_err) = linregress(x_values, y_values)

    # Calculate the regression line "y values" from the slope and intercept.
    regress_values = x_values * slope + intercept
    # Get the equation of the line.
    line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
    # Create a scatter plot and plot the regression line.
    plt.scatter(x_values,y_values)
    plt.plot(x_values,regress_values,"r")
    # Annotate the text for the line equation.
    plt.annotate(line_eq, text_coordinates, fontsize=15, color="red")
    plt.title(title)
    plt.xlabel('Latitude')
    plt.ylabel(y_label)
    plt.show()

# %%
index13 = city_data_df.loc[13]
index13
# Out:
# City                       Bethel
# Country                        US
# Date          2021-11-23 03:34:18
# Lat                       41.3712
# Lng                       -73.414
# Max Temp                    38.05
# Humidity                       61
# Cloudiness                      1
# Wind Speed                   1.01
# Name: 13, dtype: object

# %%
city_data_df["Lat"] >= 0
# Out:
# 0      False
# 1      False
# 2      False
# 3       True
# 4       True
#        ...
# 549    False
# 550     True
# 551     True
# 552     True
# 553     True
# Name: Lat, Length: 554, dtype: bool

# %%
# Create Northern and Southern Hemisphere DataFrames.
northern_hemi_df = city_data_df.loc[(city_data_df["Lat"] >= 0)]
southern_hemi_df = city_data_df.loc[(city_data_df["Lat"] < 0)]

# %%
# Linear regression on the Northern Hemisphere
x_values = northern_hemi_df["Lat"]
y_values = northern_hemi_df["Max Temp"]
# Call the function.
plot_linear_regression(x_values, y_values,
                       'Linear Regression on the Northern Hemisphere \
                        for Maximum Temperature', 'Max Temp',(10,40))

# %%
# Linear regression on the Southern Hemisphere
x_values = southern_hemi_df["Lat"]
y_values = southern_hemi_df["Max Temp"]
# Call the function.
plot_linear_regression(x_values, y_values,
                       'Linear Regression on the Southern Hemisphere \
                        for Maximum Temperature', 'Max Temp',(-50,90))

# %%
# Linear regression on the Northern Hemisphere
x_values = northern_hemi_df["Lat"]
y_values = northern_hemi_df["Humidity"]
# Call the function.
plot_linear_regression(x_values, y_values,
                       'Linear Regression on the Northern Hemisphere \
                        for % Humidity', '% Humidity',(40,10))

# %%
# Linear regression on the Southern Hemisphere
x_values = southern_hemi_df["Lat"]
y_values = southern_hemi_df["Humidity"]
# Call the function.
plot_linear_regression(x_values, y_values,
                       'Linear Regression on the Southern Hemisphere \
                        for % Humidity', '% Humidity',(-50,15))

# %%
# Linear regression on the Northern Hemisphere
x_values = northern_hemi_df["Lat"]
y_values = northern_hemi_df["Cloudiness"]
# Call the function.
plot_linear_regression(x_values, y_values,
                       'Linear Regression on the Northern Hemisphere \
                        for %Cloudiness', '% Cloudiness',(40,10))

# %%
# Linear regression on the Southern Hemisphere
x_values = southern_hemi_df["Lat"]
y_values = southern_hemi_df["Cloudiness"]
# Call the function.
plot_linear_regression(x_values, y_values,
                       'Linear Regression on the Southern Hemisphere \
                        for % Cloudiness', '% Cloudiness',(-50,60))

# %%
# Linear regression on the Northern Hemisphere
x_values = northern_hemi_df["Lat"]
y_values = northern_hemi_df["Wind Speed"]
# Call the function.
plot_linear_regression(x_values, y_values,
                       'Linear Regression on the Northern Hemisphere \
                        for Wind Speed', 'Wind Speed',(40,35))

# %%
# Linear regression on the Southern Hemisphere
x_values = southern_hemi_df["Lat"]
y_values = southern_hemi_df["Wind Speed"]
# Call the function.
plot_linear_regression(x_values, y_values,
                       'Linear Regression on the Southern Hemisphere \
                        for Wind Speed', 'Wind Speed',(-50,35))
